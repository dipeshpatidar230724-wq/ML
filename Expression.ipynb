# %% [markdown]
# <a href="https://colab.research.google.com/github/dipeshpatidar230724-wq/ML/blob/main/Expression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=9
print(n,'binary',format(n,'b'))
print(n,'* 2 =',n<<1,format(n<<1,'b'))
print(n,'/ 2 =',n>>1,format(n>>1,'b'))
# Out:
# 9 binary 1001
# 9 * 2 = 18 10010
# 9 / 2 = 4 100

# %%
x = True
y  = False
print('x and y is',x & y)
print('x or y is',x | y)
print('not x is',not x)
# Out:
# x and y is False
# x or y is True
# not x is False

# %%
x = 12
y = 4
print(x & y)
print(x | y)
print(x ^ y)
# Out:
# 4
# 12
# 8

# %%
x = 'Hello'
print("H" in x)
print("h" not in x)
# Out:
# True
# True

# %%
import cmath
a = complex(20+5j)
b = complex(5+3j)
print('a+b',a+b)
print('a-b',a-b)
print('a*b',a*b)
print('a/b',a/b)
# Out:
# a+b (25+8j)
# a-b (15+2j)
# a*b (85+85j)
# a/b (3.3823529411764706-1.0294117647058825j)

# %%
import cmath
a = int(input("Enter length of triangle: "))
b = int(input("Enter breadth of triangle: "))
c = int(input("Enter height of triangle: "))
s = (a+b+c)/2
print(s)
ar = cmath.sqrt(s*(s-a)*(s-b)*(s-c))
print(ar)
# Out:
# Enter length of triangle: 2
# Enter breadth of triangle: 3
# Enter height of triangle: 4
# 4.5
# (2.9047375096555625+0j)

# %%
a = input("Enter a character ")
ch = a.upper()
if(ch == 'a' or ch == 'e' or ch == 'i' or ch == 'o' or ch == 'u'):
   print("vowel")
else:
   print("consonant")
# Out:
# Enter a character q
# consonant

# %%
a = input("Enter a value ")
if(a.isnumeric()):
   print("It is numeric")
if(a.isupper()):
   print("Charactre is Upper")
if(a.islower()):
  print("Character is lower")
# Out:
# Enter a value E
# Is Upper

# %%
n = int(input("Enter any number"))
l = [f"{n} X {i} = {n*i}" for i in range(1,10)]
print(l)
# Out:
# Enter any number4
# ['4 X 1 = 4', '4 X 2 = 8', '4 X 3 = 12', '4 X 4 = 16', '4 X 5 = 20', '4 X 6 = 24', '4 X 7 = 28', '4 X 8 = 32', '4 X 9 = 36']

# %%
import math
n = int(input("Enter any number "))
l = [math.factorial(i) for i in range(1,n+1)]
print(l)
# Out:
# Enter any number 4
# [1, 2, 6, 24]

# %%
maxNum = 0
while(True):
  n = input("Enter any number ")
  if(n == "f"):
    break
  else:
    n = int(n)
    if(n > maxNum):
      maxNum = n
print(maxNum)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15839/3121814601.py in <cell line: 0>()
#       1 maxNum = 0
#       2 while(True):
# ----> 3   n = input("Enter any number ")
#       4   if(n == "f"):
#       5     break
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
class Car:
  def __init__(self,brand,model,year):
    self.brand = brand
    self.model = model
    self.year = year
  def display_info(self):
    print(f"Car: {self.brand} {self.model} {self.year}")

car1 = Car("Toyota","Camry",2022)
car2 = Car("Honda","Civic",2021)

car1.display_info()
car2.display_info()
# Out:
# Car: Toyota Camry 2022
# Car: Honda Civic 2021

# %%
class Employee:
  def __init__(self,name,emId,salary):
    self.name = name
    self.emId = emId
    self.salary = salary
  def display_info(self):
    print(f"Employee: {self.name} {self.emId} {self.salary}")

emp1 = Employee("Rahul","emp01","20,000")
emp2 = Employee("Manish","emp02","10,000")

emp1.display_info()
emp2.display_info()

# %%
class Student:
  def __init__(self,name,age,marks):
     self.name = name
     self.age = age
     self.marks = marks
  def display_info(self):
    print(f"Student: {self.name} {self.age} {self.marks})

  student = [
      Student("Rahul","23","20"),
      Student("Manish","22","25")
  ]
 for(student):
  print(student.display_info())

# %%
class Employee:
  def __init__(self,name,emId,salary):
    self.name = name
    self.emId = emId
    self.salary = salary
employees = {
    101: {"name": "Rahul", "salary": 50000},
    102: {"name": "Manish", "salary": 60000},
    103: {"name": "Vikash", "salary": 55000
}
for emp_id, emp in employees.items():
  print(f"Employee ID: {emp_id}, Name: {emp['name']}, Salary: {emp['salary']}")
