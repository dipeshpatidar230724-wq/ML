# %% [markdown]
# <a href="https://colab.research.google.com/github/dipeshpatidar230724-wq/ML/blob/main/Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# EXPERI

# %%
# Dipesh Patidar
def funct1():
  print("hello")
funct1()
# Out:
# hello

# %%
def funct1(fname):
  print(fname)
funct1("fchchg")
# Out:
# fchchg

# %%
def funct1(fname, lname ):
  print(fname + "  " +lname)
funct1("fchchg", "vsdvhsg")
# Out:
# fchchg  vsdvhsg

# %%
def funct1(*kid):
  print(kid[2])
funct1("a", "b", "c")
funct1("a", "b", "r", "d")
funct1("a", "b", "t", "d", "e")
# Out:
# c
# r
# t

# %%
def funct1( k,j,i):
  print(" the values of i = {}, j={}, k={}" .format(i,j,k))

funct1(i=2, j=6, k=8)
# Out:
#  the values of i = 2, j=6, k=8

# %%
def funct1( ** var):
   print(var["i"])
funct1(i=2, j=6, k=8)
# Out:
# 2

# %%
def funct1(food):
  for i in food:
    print(i)

fruits=["apple", "banana", "cherry"]
funct1(fruits)
# Out:
# apple
# banana
# cherry

# %%
def funct1 (country='India'):
  print ("my country name is " + country)
funct1("newyork")
funct1()
# Out:
# my country name is newyork
# my country name is India

# %%
def funct1 (x):
  return 5*x

print(funct1(5))
# Out:
# 25

# %%
def funct1 ():
  pass

# %%
x=10
def funct1():
  x=10
  x= x*10
  print(x)

funct1()
print(x)
# Out:
# 100
# 10

# %%
x=10
def funct1():
  x=globals()['x']
  x=10
  x= x*10
  globals()['x']=x
  print(x)

funct1()
print(x)
# Out:
# 100
# 100

# %%
x=10
def funct1():
  global x
  x= x*100
  print(x)

funct1()
print(x)
# Out:
# 1000
# 1000

# %%
# explicitly float accept  what to do
def greet(name:float):
  print(type(name))
greet(1234)
greet("welcome")
# Out:
# <class 'int'>
# <class 'str'>

# %%
num= input("enter a number")
num
# Out:
# enter a number12
# '12'

# %%
str= input("enter a string "). split(",")
# Out:
# enter a string Dipesh Patidar

# %%
str
# Out:
# ['Dipesh Patidar']

# %%
print(1,2,3,4)
# Out:
# 1 2 3 4

# %%
print(1,2,3,4, sep='*')
# Out:
# 1*2*3*4

# %%
print(1,2,3,4, sep='*' ,end= '&')
print(1,2,3,4, sep='*')
# Out:
# 1*2*3*4&1*2*3*4

# %%
x=3;y=4
print( "vcnsv{1}jhsjhd{0}" . format(x,y))
# Out:
# vcnsv4jhsjhd3

# %%
print( "{}jghcjgcj{}" . format('bread', 'butter'))
print( "{1}jghcjgcj{0}" . format('bread', 'butter'))
# Out:
# breadjghcjgcjbutter
# butterjghcjgcjbread

# %%
def greet(name="Guest"):
  print(f"Hello, {name}!")

greet("Alice")
greet()
# Out:
# Hello, Alice!
# Hello, Guest!

# %%
def get_min_max(numbers):
  return min(numbers), max(numbers)

nums = [10, 5, 20, 8, 15]
min_val, max_val = get_min_max(nums)
print(f"Min: {min_val}, Max: {max_val}")
# Out:
# Min: 5, Max: 20

# %%
multiply = lambda a, b: a * b

print(f"5 * 3 = {multiply(5, 3)}")
# Out:
# 5 * 3 = 15

# %%
def factorial(n):
  if n == 0 or n == 1:
    return 1
  else:
    return n * factorial(n-1)

print(f"Factorial of 5: {factorial(5)}")
# Out:
# Factorial of 5: 120

# %%
def add(a, b):
  """This function adds two numbers and returns the sum."""
  return a + b

print(f"2 + 3 = {add(2, 3)}")
print(add.__doc__)
# Out:
# 2 + 3 = 5
# This function adds two numbers and returns the sum.

# %%
def divide(a: float, b: float) -> float:
  return a / b

print(f"10.0 / 2.5 = {divide(10.0, 2.5)}")
# Out:
# 10.0 / 2.5 = 4.0

# %%
def outer_func(message):
  def inner_func():
    print(message)
  return inner_func

say_hello = outer_func("Hello from a closure!")
say_hello()
# Out:
# Hello from a closure!
